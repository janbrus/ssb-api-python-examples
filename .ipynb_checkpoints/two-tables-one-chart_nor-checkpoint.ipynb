# %% [markdown]
# # Kombinere tall fra to tabeller i Statistikkbanken i en figur.
# ## Eksempel Konsumprisindeksen: KPI og KPI-JAE

# %% [markdown]
# Kombinerer data fra Statistikkbanktabellene [03013](https://www.ssb.no/statbank/table/03013) og [05327](https://www.ssb.no/statbank/table/05327)
# ![tab05327.png](attachment:tab05327.png)

# %%
# Her importerer vi ulike pakker
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pyjstat import pyjstat  # pyjstat er for behandling av JSON-stat

# %% [markdown]
#  Funksjon for å konvertere til datoformat og sette dette som en Pandas PeriodIndex,
#  Returnerer i tillegg navnet på frekvens-kolonnen

# %%
def dateConv(dataframe):
    frekvens, frek_no, frek_en, fmt = findFrequency(dataframe)
    setPeriodIndex(frekvens, frek_no, frek_en, fmt, dataframe)

    #funksjon for for å finne frekvenskolonne    
def findFrequency(dataframe):
    frekvenser = ['måned', 'kvartal', 'uke', 'år', 'year', 'quarter', 'month', 'week']
    frek_no = ''
    freq_en = ''
    fmt = ''
    for w in frekvenser:
        if w in dataframe.columns:
            if w in ['måned', 'month']:
                frek_no = 'M'
                frek_en = 'M'
                fmt = '%YM%m'
            elif w in ['kvartal', 'quarter']:
                frek_no = 'K'
                frek_en = 'Q'
                fmt = '%YK%q'
            elif w in ['uke', 'week']:
                frek_no = 'U';
                frek_en = 'W'
                fmt = '%YW%W-%w'
            else:
                frek_no = ''
                frek_en = 'A'
            return w, frek_no, frek_en, fmt
    
# funksjon for å sette index som PeriodIndex,       
def setPeriodIndex(frekvens, frek_no, freq_en, fmt, df):
    if frekvens in ['kvartal', 'quarter']:
        # erstatter K med Q, konverterr til datoformat og setter frekensen til Pandas PeriodIndex
        df.index = pd.PeriodIndex(pd.to_datetime(df[frekvens].str.replace(frek_no, freq_en), errors='coerce'), freq='Q-DEC')
    elif frekvens in ['uke', 'week']:
        df.index = pd.PeriodIndex(pd.to_datetime(df[frekvens].str.replace(frek_no, freq_en).add('-0'), format= fmt, errors='coerce'), freq='W-MON')
    else:
        df.index =  pd.PeriodIndex(pd.to_datetime(df[frekvens], format= fmt, errors='coerce'), freq=freq_en)
    return frekvens

# %% [markdown]
# URL til tabellenes metadata i PxWebApi, som vi skal poste spørringene mot

# %%
URL1 = 'https://data.ssb.no/api/v0/no/table/05327' # KPI-jae
URL2 = 'https://data.ssb.no/api/v0/no/table/03013' # KPI total

# %% [markdown]
# API-spørring i JSON mot tabell 05327 - siste 5 år

# %%
sp1 = {
  "query": [
    {
      "code": "Konsumgrp",
      "selection": {
        "filter": "item",
        "values": ['JA_TOTAL', 'JAE_TOTAL', 'JE_TOTAL', 'JEL_TOTAL']
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": ["KPIJustIndMnd"]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "top",
        "values": [ "60" ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %% [markdown]
# JSON-spørring mot tabell 03013 siste 5 år

# %%
sp2 = {
  "query": [
    {
      "code": "Konsumgrp",
      "selection": {
        "filter": "item",
        "values": ["TOTAL"]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": ["KpiIndMnd"]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "top",
        "values": ["60"]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %% [markdown]
# Poster spørringene sp1 og sp2 mot metadatas url'er. Resultatene lagres som res1 og res2

# %%
res1 = requests.post(URL1, json=sp1)
res2 = requests.post(URL2, json=sp2)

# %% [markdown]
# Leser resultatet med JSON-stat biblioteket pyjstat

# %%
ds1 = pyjstat.Dataset.read(res1.text)
ds2 = pyjstat.Dataset.read(res2.text)

# %% [markdown]
# Skriver dette til to Pandas dataframes, df1 og df2.

# %%
df1 = ds1.write('dataframe')
df2 = ds2.write('dataframe')

# %%
df1.head(7)
# Out:
#          konsumgruppe                                 statistikkvariabel  \
# 0  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 1  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 2  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 3  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 4  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 5  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 6  KPI-JA Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
#
#      måned  value
# 0  2016M04  102.8
# 1  2016M05  103.1
# 2  2016M06  103.7
# 3  2016M07  104.4
# 4  2016M08  103.7
# 5  2016M09  104.1
# 6  2016M10  104.6

# %%
df1.tail() # slutten av datasettet
# Out:
#             konsumgruppe                                 statistikkvariabel  \
# 235  KPI-JEL Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 236  KPI-JEL Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 237  KPI-JEL Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 238  KPI-JEL Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
# 239  KPI-JEL Totalindeks  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...
#
#        måned  value
# 235  2020M11  112.1
# 236  2020M12  112.1
# 237  2021M01  112.1
# 238  2021M02  112.7
# 239  2021M03  112.9

# %% [markdown]
# Kaller funksjonen for datokonvertering. *Kan sløyfes*.

# %%
dateConv(df1)

# %%
df1.index
# Out:
# PeriodIndex(['2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09',
#              '2016-10', '2016-11', '2016-12', '2017-01',
#              ...
#              '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11',
#              '2020-12', '2021-01', '2021-02', '2021-03'],
#             dtype='period[M]', name='måned', length=240, freq='M')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 240 entries, 2016-04 to 2021-03
# Freq: M
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   konsumgruppe        240 non-null    object
#  1   statistikkvariabel  240 non-null    object
#  2   måned               240 non-null    object
#  3   value               240 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 9.4+ KB

# %%
df1.tail(15)
# Out:
#                 konsumgruppe  \
# måned
# 2020-01  KPI-JEL Totalindeks
# 2020-02  KPI-JEL Totalindeks
# 2020-03  KPI-JEL Totalindeks
# 2020-04  KPI-JEL Totalindeks
# 2020-05  KPI-JEL Totalindeks
# 2020-06  KPI-JEL Totalindeks
# 2020-07  KPI-JEL Totalindeks
# 2020-08  KPI-JEL Totalindeks
# 2020-09  KPI-JEL Totalindeks
# 2020-10  KPI-JEL Totalindeks
# 2020-11  KPI-JEL Totalindeks
# 2020-12  KPI-JEL Totalindeks
# 2021-01  KPI-JEL Totalindeks
# 2021-02  KPI-JEL Totalindeks
# 2021-03  KPI-JEL Totalindeks
#
#                                         statistikkvariabel    måned  value
# måned
# 2020-01  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M01  110.1
# 2020-02  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M02  110.5
# 2020-03  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M03  110.7
# 2020-04  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M04  111.5
# 2020-05  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M05  111.6
# 2020-06  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M06  112.1
# 2020-07  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M07  112.9
# 2020-08  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M08  112.3
# 2020-09  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M09  112.5
# 2020-10  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M10  112.6
# 2020-11  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M11  112.1
# 2020-12  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2020M12  112.1
# 2021-01  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2021M01  112.1
# 2021-02  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2021M02  112.7
# 2021-03  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2021M03  112.9

# %%
dateConv(df2) # kan sløyfes eller kommenteres ut.

# %% [markdown]
# Plot av df2 blir riktig, for her er det bare en serie

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='måned'>

# %% [markdown]
# Standard plot av df1 gir alle 4 intervallene. Resultat er avhengig av om det er dato eller kategori på x-aksen.

# %%
df1.plot() # standard plot gir alle 4 intervallene og resultat er avhengig av om det er dato eller kategori på x-aksen
# Out:
# <AxesSubplot:xlabel='måned'>

# %% [markdown]
# ### slår sammen de to "dataframene"  df1 og df2 med en enkel concat til datasettet "sammen"

# %%
sammen = pd.concat([df1,df2])

# %% [markdown]
# Viser topp og bunn for det sammeslåtte datasettet

# %%
sammen.head()
# Out:
#                konsumgruppe  \
# måned
# 2016-04  KPI-JA Totalindeks
# 2016-05  KPI-JA Totalindeks
# 2016-06  KPI-JA Totalindeks
# 2016-07  KPI-JA Totalindeks
# 2016-08  KPI-JA Totalindeks
#
#                                         statistikkvariabel    måned  value
# måned
# 2016-04  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2016M04  102.8
# 2016-05  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2016M05  103.1
# 2016-06  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2016M06  103.7
# 2016-07  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2016M07  104.4
# 2016-08  KPI-JA, KPI-JAE. KPI-JE og KPI-JEL (2015=100) ...  2016M08  103.7

# %%
sammen.tail()
# Out:
#         konsumgruppe           statistikkvariabel    måned  value
# måned
# 2020-11  Totalindeks  Konsumprisindeks (2015=100)  2020M11  112.4
# 2020-12  Totalindeks  Konsumprisindeks (2015=100)  2020M12  112.9
# 2021-01  Totalindeks  Konsumprisindeks (2015=100)  2021M01  114.1
# 2021-02  Totalindeks  Konsumprisindeks (2015=100)  2021M02  114.9
# 2021-03  Totalindeks  Konsumprisindeks (2015=100)  2021M03  114.6

# %% [markdown]
# ### Omstrukturerer (pivoterer) tabellen for å få en bedre visning
#
# ["tidy data" Hadley Wickham](https://vita.had.co.nz/papers/tidy-data.pdf)

# %%
df3 = sammen.pivot(columns='konsumgruppe', values='value')

# uten kall til dateconv() bruk måned som index slik
# df3 = sammen.pivot(index='måned', columns='konsumgruppe', values='value')

# %%
df3.head(3)
# Out:
# konsumgruppe  KPI-JA Totalindeks  KPI-JAE Totalindeks  KPI-JE Totalindeks  \
# måned
# 2016-04                    102.8                102.6               102.7
# 2016-05                    103.1                103.0               103.0
# 2016-06                    103.7                103.4               103.5
#
# konsumgruppe  KPI-JEL Totalindeks  Totalindeks
# måned
# 2016-04                     102.4        102.9
# 2016-05                     102.8        103.2
# 2016-06                     103.4        103.8

# %%
df3.index
# Out:
# PeriodIndex(['2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09',
#              '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03',
#              '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09',
#              '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03',
#              '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09',
#              '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03',
#              '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09',
#              '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03',
#              '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09',
#              '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03'],
#             dtype='period[M]', name='måned', freq='M')

# %%
df3.tail(3)
# Out:
# konsumgruppe  KPI-JA Totalindeks  KPI-JAE Totalindeks  KPI-JE Totalindeks  \
# måned
# 2021-01                    114.5                112.5               112.1
# 2021-02                    115.3                113.0               112.6
# 2021-03                    115.0                113.3               112.9
#
# konsumgruppe  KPI-JEL Totalindeks  Totalindeks
# måned
# 2021-01                     112.1        114.1
# 2021-02                     112.7        114.9
# 2021-03                     112.9        114.6

# %% [markdown]
# ### Figur med Pandas innebygde plot-funksjon

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='måned'>

# %% [markdown]
# Plot med flere parametre

# %%
df3.plot(marker="o", markersize=3, figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='måned'>

# %% [markdown]
# Lagrer figurvisningen som en funksjon. Her er også SSBfarger definert. Du kan gi høyde og bredde som parametre

# %%
def visfigur(bredde=12, hoyde=6):
    fig, ax = plt.subplots(figsize=(bredde, hoyde))  
    #definerer ssb farger på figurene
    ssbCol = ['#1a9d49', '#075745', '#1d9de2', '#0f2080', '#c78800', '#471f00', '#c775a7', '#a3136c', '#909090', '#000000']
    plt.xlabel('måned') 
    plt.ylabel('index')
    ax.set_title('Figur som viser KPI total og undeliggende KPI serier')
    df3.plot(ax=ax, color=ssbCol)
    plt.show()

# %%
visfigur()

# %% [markdown]
# ### Plot med ulike stiler
# I Matplotlib kan du prøve ut ulike ferdige stiler. Vi kan evt. lage vår egen etter SSBs designmal.
#
# Prøv ut: 'Solarize_Light2',  'bmh', 'classic', 'dark_background' 'fivethirtyeight', 'seaborn-talk'

# %%
with plt.style.context('Solarize_Light2'):
    visfigur()

# %%
with plt.style.context('fivethirtyeight'):
    visfigur(16, 9)
