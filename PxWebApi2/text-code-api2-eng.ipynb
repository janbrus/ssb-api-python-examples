# %% [markdown]
# # Query that returns both text (name) and code (ID) from JSON-stat
# ### Example: HS codes for foreign trade

# %% [markdown]
# ### Import libraries
# Uses [pyjstat](https://pypi.org/project/pyjstat/) and pandas.

# %%
from pyjstat import pyjstat  
import pandas as pd  # Pandas is actually loaded as part of pyjstat
import requests

# %% [markdown]
# Import/Export all product codes to US for the last month, approx. 65,000 cells. Max limit for a query in PxWebApi is 800,000 cells, including empty cells.

# %% [markdown]
# ### URL with the table's metadata

# %% [markdown]
# GET_URL = https://data.ssb.no/api/pxwebapi/v2/tables/08801/data?lang=en&valueCodes[Varekoder]=*&valueCodes[ImpEks]=1,2&valueCodes[ContentsCode]=Mengde1,Verdi,Mengde2&valueCodes[Tid]=2024&codelist[Varekoder]=vs_VareKoderKN8Siff&codelist[Land]=vs_LandKoderAlf1
#
# JSON-stat2 is the default output format. You can also add others with `&outputFormat=` such as csv or xlsx.
#
# Note that the API URLs are *not* case-sensitive.
#
# Showing the individual elements. The codelist elements are in most cases superfluous/redundant and can be removed.

# %%
# The individual elements in the query

tabid = "08799" # can be changed to the annual table 08801, without other changes
lang = "lang=en" # language code can also be "en"
get_stem = "https://data.ssb.no/api/pxwebapi/v2/tables/" + tabid + "/data?" + lang   # 'https://data.ssb.no/api/v0/no/table/08799'
get_query = "&valueCodes[Varekoder]=*\
&valueCodes[ImpEks]=1,2\
&valueCodes[Land]=US\
&valueCodes[ContentsCode]=Mengde1,Verdi,Mengde2\
&valueCodes[Tid]=top(1)"

# %% [markdown]
# Import/Export all product codes to US for the last month, approx. 65,000 cells. Max limit for a query in PxWebApi is 800,000 cells, including empty cells.

# %%
GET_URL = get_stem + get_query

# %% [raw]
# ### Execute the query

# %%
res = requests.get(GET_URL)

# %% [markdown]
# HTTP code 200 is OK

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# ### Read the JSON-stat result using the pyjstat library
# Store it as dataset ds.

# %%
ds = pyjstat.Dataset.read(res.text)

# %%
type(ds)
# Out:
# pyjstat.pyjstat.Dataset

# %% [markdown]
# View the dataset ds - big dataset

# %%
# ds

# %% [markdown]
# ### Fetch some top-level metadata from the JSON-stat dataset

# %%
tittel = ds['label']
print(tittel)
# Out:
# 08799: External trade in goods, by commodity number, imports/exports, country, contents and month

# %% [markdown]
# Last Updated as GMT

# %%
last_update = ds['updated']
print(last_update)
# Out:
# 2025-10-15T06:00:00Z

# %% [markdown]
# Fetch source

# %%
source = ds['source']
print(source)
# Out:
# Statistics Norway

# %% [markdown]
# Roles provide some shortcuts to the IDs of fixed dimensions in the dataset

# %%
ds_roles = ds['role']
print(ds_roles)
# Out:
# OrderedDict({'time': ['Tid'], 'geo': ['Land'], 'metric': ['ContentsCode']})

# %% [markdown]
# ### Create dataframes
# We need to create two dataframes, one with text and one with ID. Pyjstat only allows either/or

# %%
hstrade = ds.write('dataframe')
hstrade_id = ds.write('dataframe', naming='id')

# %%
hstrade.head()
# Out:
#                                     commodity number imports/exports  \
# 0  Imports of unspecified goods, with duty (1988-...         Imports
# 1  Imports of unspecified goods, with duty (1988-...         Imports
# 2  Imports of unspecified goods, with duty (1988-...         Imports
# 3  Imports of unspecified goods, with duty (1988-...         Exports
# 4  Imports of unspecified goods, with duty (1988-...         Exports
#
#                     country         contents    month  value
# 0  United States of America  Quantity 1 (Q1)  2025M09      0
# 1  United States of America      Value (NOK)  2025M09      0
# 2  United States of America  Quantity 2 (Q2)  2025M09      0
# 3  United States of America  Quantity 1 (Q1)  2025M09      0
# 4  United States of America      Value (NOK)  2025M09      0

# %%
hstrade_id.head()
# Out:
#        Varekoder ImpEks Land ContentsCode      Tid  value
# 0  00000011_1988      1   US      Mengde1  2025M09      0
# 1  00000011_1988      1   US        Verdi  2025M09      0
# 2  00000011_1988      1   US      Mengde2  2025M09      0
# 3  00000011_1988      2   US      Mengde1  2025M09      0
# 4  00000011_1988      2   US        Verdi  2025M09      0

# %% [markdown]
# ### Create a new column with both HS product code and text combined

# %%
hstrade['hstrade_combi'] = hstrade_id['Varekoder'] + ' ' + hstrade['commodity number']

# %%
hstrade.columns
# Out:
# Index(['commodity number', 'imports/exports', 'country', 'contents', 'month',
#        'value', 'hstrade_combi'],
#       dtype='object')

# %% [markdown]
# ### Create a new dataframe with only the columns we want, in new order.
# Note double [[ ]] to create dataframe

# %%
hstrade_new = hstrade[['hstrade_combi', 'imports/exports', 'country', 'contents', 'month',
       'value']]

# %%
hstrade_new.tail(10)
# Out:
#                                            hstrade_combi imports/exports  \
# 80408  99603000_2023 VOEC-shipments, goods with value...         Imports
# 80409  99603000_2023 VOEC-shipments, goods with value...         Exports
# 80410  99603000_2023 VOEC-shipments, goods with value...         Exports
# 80411  99603000_2023 VOEC-shipments, goods with value...         Exports
# 80412  99999999_1988 Total, all commodities not for p...         Imports
# 80413  99999999_1988 Total, all commodities not for p...         Imports
# 80414  99999999_1988 Total, all commodities not for p...         Imports
# 80415  99999999_1988 Total, all commodities not for p...         Exports
# 80416  99999999_1988 Total, all commodities not for p...         Exports
# 80417  99999999_1988 Total, all commodities not for p...         Exports
#
#                         country         contents    month      value
# 80408  United States of America  Quantity 2 (Q2)  2025M09          0
# 80409  United States of America  Quantity 1 (Q1)  2025M09          0
# 80410  United States of America      Value (NOK)  2025M09          0
# 80411  United States of America  Quantity 2 (Q2)  2025M09          0
# 80412  United States of America  Quantity 1 (Q1)  2025M09    8592609
# 80413  United States of America      Value (NOK)  2025M09   34056104
# 80414  United States of America  Quantity 2 (Q2)  2025M09          0
# 80415  United States of America  Quantity 1 (Q1)  2025M09   68405885
# 80416  United States of America      Value (NOK)  2025M09  482185095
# 80417  United States of America  Quantity 2 (Q2)  2025M09          0

# %% [markdown]
# Change column width.

# %%
pd.set_option('display.max_colwidth',140)

# %%
hstrade_new.tail(10)
# Out:
#                                                                                                  hstrade_combi  \
# 80408  99603000_2023 VOEC-shipments, goods with value under NOK 3 000, natural person (2023-) (Q1=kg, Q2=none)
# 80409  99603000_2023 VOEC-shipments, goods with value under NOK 3 000, natural person (2023-) (Q1=kg, Q2=none)
# 80410  99603000_2023 VOEC-shipments, goods with value under NOK 3 000, natural person (2023-) (Q1=kg, Q2=none)
# 80411  99603000_2023 VOEC-shipments, goods with value under NOK 3 000, natural person (2023-) (Q1=kg, Q2=none)
# 80412                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
# 80413                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
# 80414                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
# 80415                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
# 80416                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
# 80417                        99999999_1988 Total, all commodities not for publication (1988-) (Q1=kg, Q2=none)
#
#       imports/exports                   country         contents    month  \
# 80408         Imports  United States of America  Quantity 2 (Q2)  2025M09
# 80409         Exports  United States of America  Quantity 1 (Q1)  2025M09
# 80410         Exports  United States of America      Value (NOK)  2025M09
# 80411         Exports  United States of America  Quantity 2 (Q2)  2025M09
# 80412         Imports  United States of America  Quantity 1 (Q1)  2025M09
# 80413         Imports  United States of America      Value (NOK)  2025M09
# 80414         Imports  United States of America  Quantity 2 (Q2)  2025M09
# 80415         Exports  United States of America  Quantity 1 (Q1)  2025M09
# 80416         Exports  United States of America      Value (NOK)  2025M09
# 80417         Exports  United States of America  Quantity 2 (Q2)  2025M09
#
#            value
# 80408          0
# 80409          0
# 80410          0
# 80411          0
# 80412    8592609
# 80413   34056104
# 80414          0
# 80415   68405885
# 80416  482185095
# 80417          0
