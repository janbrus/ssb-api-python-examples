# %% [markdown]
# # Simple example - get CSV from API to Python pandas
# ## Make simple chart based on a small dataset from Statistics Norway's API: readymade datasets
# ### We use the datasaset  [index on retail sales](https://data.ssb.no/api/v0/dataset/1066?lang=en) as CSV

# %%
# show plot in notebook
# %matplotlib inline

# %% [markdown]
# import Python pandas in order to make a dataframe

# %%
# Import Python pandas in order to make a dataframe 
import pandas as pd

# %% [markdown]
# Get content from the API and put it in 'df'. In order to get æøå correct from csv give the parameter encoding

# %%
df = pd.read_csv("https://data.ssb.no/api/v0/dataset/1066.csv?lang=en", encoding = "ISO-8859-1")

# %% [markdown]
# Shape shows number of rows and columns

# %%
df.shape
# Out:
# (13, 4)

# %% [markdown]
# The top of the dataset

# %%
df.head()
# Out:
#                                             industry    month  \
# 0  47 Retail trade, except of motor vehicles and ...  2018M07
# 1  47 Retail trade, except of motor vehicles and ...  2018M08
# 2  47 Retail trade, except of motor vehicles and ...  2018M09
# 3  47 Retail trade, except of motor vehicles and ...  2018M10
# 4  47 Retail trade, except of motor vehicles and ...  2018M11
#
#                            contents  \
# 0  Volume index seasonally adjusted
# 1  Volume index seasonally adjusted
# 2  Volume index seasonally adjusted
# 3  Volume index seasonally adjusted
# 4  Volume index seasonally adjusted
#
#    07129: Index of retail sales, by industry, month and contents
# 0                                              102.4
# 1                                              102.9
# 2                                              102.4
# 3                                              102.1
# 4                                              103.4

# %%
df['month']= pd.to_datetime(df['month'].str.replace('M', '-'))

# %%
df.index = df['month']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13 entries, 2018-07-01 to 2019-07-01
# Data columns (total 4 columns):
# industry                                                         13 non-null object
# month                                                            13 non-null datetime64[ns]
# contents                                                         13 non-null object
# 07129: Index of retail sales, by industry, month and contents    13 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 520.0+ bytes

# %%
df.plot(x='month', y='07129: Index of retail sales, by industry, month and contents', figsize=(12, 6), color='g')

# %% [markdown]
# Alternative: Month and values to a series object

# %%
series1=df['07129: Index of retail sales, by industry, month and contents']

# %% [markdown]
# Basic plot

# %%
series1.plot()
